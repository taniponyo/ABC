# %%
N = int(input())
S = input()
# Out:
# 999999 999999

# %%
S1 = []
S2 = []

for i in range(int(N/2)):
    S1.append(S[i])
    S2.append(S[i+int(N/2)])
    
if S1 == S2:
    if N%2 == 1:
        print('No')
    else:
        print('Yes')
else:
    print('No')
